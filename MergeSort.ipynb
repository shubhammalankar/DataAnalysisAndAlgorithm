# %%
#mergeSort.py CODE - 
import math
def merge(A,p,q,r):
    print("Inside merge A =",A," p = ",p," q = ",q," r = ",r)
    n1 = q-p+1#n1 = 1
    n2 = r-q#n2 = 1
    print("n1 = ",n1)
    print("n2 = ",n2)
    l = []
    m = []
    for i in range(0,n1):
        print("A[p+i]",p+i)#0
        l.append(A[p+i])
    #l.append("null")
    for j in range(0,n2):
        print("A[q+j+1]",q+j+1)#1
        m.append(A[q+j+1])
    #m.append("null")
    print("Array in merge l - ",l)
    print("Array in merge m- ",m)    
    a=0
    b=0
    print("Values of p = ",p)
    print("Values of r = ",r)
    r=r+1
    print("Values of r+1 = ",r)
    for k in range (p,r):#iterete from 0 to 2
        print("Array in merge forloop A - ",A)
        print("Values of k = ",k)
        print("Values of a = ",a)
        print("Values of b = ",b)
        print("Array in merge l[a] - ",l[a])
        print("Array in merge m[b]- ",m[b]) 
        if(l[a] == "null"):
            print("l[a] is null")
            A[k]=m[b]
            b=b+1
        elif(m[b] == "null"):
            print("m[b] is null")
            A[k]=l[a]
            a=a+1
        elif(l[a]<=m[b]):
            print("inside if loop - ")
            A[k]=l[a]
            a=a+1
        else:
            print("inside else loop - ")
            A[k]=m[b]
            b=b+1
        #if(l[a]>m[b]):
    print("out of for loop Array in merge forloop A - ",A)
def mergeSort(A,p,r):
    print(A,"  ",p,"  ",r)
    for i in range(p,r):

        print(A[i])
    if p < r and len(A)>1:
    #if p < r:
        print("Inside if loop")
        #if (int(round((p+r)/2)) == 0):
         #   print(int(round((p+r)/2)))
        #else:
        mid=int((p+r)/2)
        print("value of mid = ",mid)
        print("Inside mergeSort1 loop")
        mergeSort(A,p,mid)
        print("Inside mergeSort2 loop")
        mergeSort(A,mid+1,r)  # I think this might be affecting the flow but is working fine with small set of array
        print("Inside merge loop")
        merge(A,p,mid,r)
    else:
        print("--------------------------continue")
        
if __name__ == "__main__":
    print("Inside main statement")
    #A = [89,54,14,68,23,6,44]
    A = [89,54,14,68]
    mergeSort(A,0,len(A))
# Out:
# Inside main statement
# [89, 54, 14, 68]    0    4
# 89
# 54
# 14
# 68
# Inside if loop
# value of mid =  2
# Inside mergeSort1 loop
# [89, 54, 14, 68]    0    2
# 89
# 54
# Inside if loop
# value of mid =  1
# Inside mergeSort1 loop
# [89, 54, 14, 68]    0    1
# 89
# Inside if loop
# value of mid =  0
# Inside mergeSort1 loop
# [89, 54, 14, 68]    0    0
# --------------------------continue
# Inside mergeSort2 loop
# [89, 54, 14, 68]    1    1
# --------------------------continue
# Inside merge loop
# Inside merge A = [89, 54, 14, 68]  p =  0  q =  0  r =  1
# n1 =  1
# n2 =  1
# A[p+i] 0
# A[q+j+1] 1
# Array in merge l -  [89]
# Array in merge m-  [54]
# Values of p =  0
# Values of r =  1
# Values of r+1 =  2
# Array in merge forloop A -  [89, 54, 14, 68]
# Values of k =  0
# Values of a =  0
# Values of b =  0
# Array in merge l[a] -  89
# Array in merge m[b]-  54
# inside else loop -
# Array in merge forloop A -  [54, 54, 14, 68]
# Values of k =  1
# Values of a =  0
# ...
